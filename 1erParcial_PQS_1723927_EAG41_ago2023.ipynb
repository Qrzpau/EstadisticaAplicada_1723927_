# %% [markdown]
# ## Estadística Aplicada
# Paulina Quiroz Sánchez 1723927
#
# Grupo 41
#
# Primer Exámen Parcial

# %% [markdown]
# ## 1. a) Cuantas  películas  hay,  cuantos  géneros,  y  cuanto  duran  en promedio  las películas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

pelis = pd.read_csv('https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/peliculas.csv')

num_peliculas = len(pelis)

num_generos = len(set(pelis['category']))

duracion_promedio = pelis['length'].mean()

print('Número de películas:', num_peliculas)
print('Número de géneros:', num_generos)
print('Duración promedio de las películas:', duracion_promedio, 'minutos')
# Out:
# Número de películas: 1000
# Número de géneros: 17
# Duración promedio de las películas: 115.272 minutos

# %% [markdown]
# ## b) Crea  un  dataframe  llamado películas_dormir  con  las  películas  que  tienen  una duración superior a 2 horas y sean documentales

# %%
películas_dormir = pelis[(pelis['length'] > 120) & (pelis['category'] == 'Documentary')]

# %%
películas_dormir
# Out:
#                      title                                        description  \
# 39        Army Flintstones  A Boring Saga of a Database Administrator And ...
# 57     Beach Heartbreakers  A Fateful Display of a Womanizer And a Mad Sci...
# 128             Cause Date  A Taut Tale of a Explorer And a Pastry Chef wh...
# 141   Chicken Hellfighters  A Emotional Drama of a Dog And a Explorer who ...
# 155          Clerks Angels  A Thrilling Display of a Sumo Wrestler And a G...
# 205          Dancing Fever  A Stunning Story of a Explorer And a Forensic ...
# 247             Dozen Lion  A Taut Drama of a Cat And a Girl who must Defe...
# 260      Duffel Apocalypse  A Emotional Display of a Boat And a Explorer w...
# 440           Hunter Alter  A Emotional Drama of a Mad Cow And a Boat who ...
# 456     Independence Hotel  A Thrilling Tale of a Technical Writer And a B...
# 543           Madison Trap  A Awe-Inspiring Reflection of a Monkey And a D...
# ...

# %% [markdown]
# # c) Contar cuántas películas de cada género existen

# %%
conteo_por_genero = pelis['category'].value_counts()

# %%
conteo_por_genero
# Out:
# Foreign        73
# Sports         73
# Family         69
# Documentary    68
# Animation      66
# Action         64
# New            63
# Sci-Fi         61
# Drama          61
# Games          61
# Children       60
# Comedy         58
# Classics       57
# Horror         56
# Travel         56
# Music          51
# Name: category, dtype: int64

# %% [markdown]
# ## d) Calcular la duración promedio de las películas de cada género.

# %%
duracion_promedio_por_genero = pelis.groupby('category')['length'].mean().round(2)

# %%
duracion_promedio_por_genero
# Out:
# category
# Action         111.61
# Animation      111.02
# Children       109.80
# Classics       111.67
# Comedy         115.83
# Documentary    108.75
# Drama          119.89
# Family         114.78
# Foreign        121.70
# Games          127.84
# Horror         112.48
# Music          113.65
# New            111.13
# Sci-Fi         108.20
# Sports         127.51
# Travel         113.38
# Name: length, dtype: float64

# %% [markdown]
# ## e) Crear una nueva columna que indique si una película es "Corta" (duración menor a 1.5 horas), "Normal" (entre 1.5 y 2.5 horas) o "Larga" (mayor a 2.5 horas).

# %%
pelis['duracion_categoria'] = np.where(pelis['length'] < 90, 'Corta', np.where(pelis['length'] <= 150, 'Normal', 'Larga'))
pelis
# Out:
#                  title                                        description  \
# 0     Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1       Ace Goldfinger  A Astounding Epistle of a Database Administrat...
# 2     Adaptation Holes  A Astounding Reflection of a Lumberjack And a ...
# 3     Affair Prejudice  A Fanciful Documentary of a Frisbee And a Lumb...
# 4          African Egg  A Fast-Paced Documentary of a Pastry Chef And ...
# ..                 ...                                                ...
# 995     Young Language  A Unbelieveable Yarn of a Boat And a Database ...
# 996         Youth Kick  A Touching Drama of a Teacher And a Cat who mu...
# 997       Zhivago Core  A Fateful Yarn of a Composer And a Man who mus...
# 998  Zoolander Fiction  A Fateful Reflection of a Waitress And a Boat ...
# 999          Zorro Ark  A Intrepid Panorama of a Mad Scientist And a B...
#
#      release_year  rental_rate  length rating  \
# ...

# %% [markdown]
# ## 2. a) Ordena la base alfabéticamente por estado y por municipio

# %%
asgard = pd.read_csv('https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/poblacion_Asgard.csv')

asgard = asgard.sort_values(by=['Estado', 'Municipio'])

asgard
# Out:
#       País    Estado       Municipio  Población
# 16  Asgard  Alderaan     Ciudad Jedi     130312
# 1   Asgard  Alderaan   Fuente Dorada      49984
# 31  Asgard  Alderaan        Luz azul     914910
# 76  Asgard  Alderaan          Madero     774290
# 46  Asgard  Alderaan      San Isidro     159338
# ..     ...       ...             ...        ...
# 8   Asgard     Yaven       El Bosque     649663
# 83  Asgard     Yaven      Green Flag     380989
# 68  Asgard     Yaven     Santa María     111687
# 53  Asgard     Yaven     Villa Wendy     646914
# 38  Asgard     Yaven  Villa amarilla     274109
#
# [90 rows x 4 columns]

# %% [markdown]
# ## b) Cuantos  estados  hay,  cuantos  municipios  hay  en  cada  estado  y  cuantos municipios hay en total.

# %%
n_estados = asgard['Estado'].value_counts()
num_estados = n_estados.count()
num_estados

num_municipios_por_estado = asgard.groupby('Estado')['Municipio'].count()

num_municipios = asgard['Municipio'].value_counts()
num_total_municipios = num_municipios.count()
num_total_municipios

print('Número de estados:', num_estados)
print('Número de municipios en cada estado:\n', num_municipios_por_estado)
print('Número total de municipios:', num_total_municipios)
# Out:
# Número de estados: 15
# Número de municipios en cada estado:
#  Estado
# Alderaan     6
# Atlantis     6
# Endor        6
# Genosha      6
# Gotham       6
# Mandalore    6
# Mordor       6
# Mustafar     6
# Naboo        6
# Narnia       6
# Pandora      6
# Sokovia      6
# Tatooine     6
# Wakanda      6
# Yaven        6
# Name: Municipio, dtype: int64
# Número total de municipios: 59

# %% [markdown]
# ## c) Cuanta población tiene el país en total y cuanta población tiene cada estado

# %%
poblacion_total = asgard['Población'].sum()

poblacion_por_estado = asgard.groupby('Estado')['Población'].sum()

print('Población total del país:', poblacion_total)
print('Población de cada estado:', poblacion_por_estado)
# Out:
# Población total del país: 43114719
# Población de cada estado: Estado
# Alderaan     2283452
# Atlantis     3779656
# Endor        2427956
# Genosha      2871584
# Gotham       3204304
# Mandalore    2044164
# Mordor       3627119
# Mustafar     2183880
# Naboo        1602111
# Narnia       2961407
# Pandora      2959272
# Sokovia      4722224
# Tatooine     2770055
# Wakanda      2905562
# Yaven        2771973
# Name: Población, dtype: int64

# %% [markdown]
# ## d) Calcula la mediana de la población de los municipios, y clasifícalos, aquellos por arriba de la mediana deben llamarse “muy poblados” y aquellos debajo de la mediana “poco poblados”

# %%
mediana_poblacion = asgard['Población'].median()
asgard['clasificacion'] = np.where(asgard['Población'] >= mediana_poblacion, 'muy poblados', 'poco poblados')
asgard
# Out:
#       País    Estado       Municipio  Población  clasificacion
# 16  Asgard  Alderaan     Ciudad Jedi     130312  poco poblados
# 1   Asgard  Alderaan   Fuente Dorada      49984  poco poblados
# 31  Asgard  Alderaan        Luz azul     914910   muy poblados
# 76  Asgard  Alderaan          Madero     774290   muy poblados
# 46  Asgard  Alderaan      San Isidro     159338  poco poblados
# ..     ...       ...             ...        ...            ...
# 8   Asgard     Yaven       El Bosque     649663   muy poblados
# 83  Asgard     Yaven      Green Flag     380989  poco poblados
# 68  Asgard     Yaven     Santa María     111687  poco poblados
# 53  Asgard     Yaven     Villa Wendy     646914   muy poblados
# 38  Asgard     Yaven  Villa amarilla     274109  poco poblados
#
# [90 rows x 5 columns]

# %% [markdown]
# ## e) Encuentra  los  5  municipios  mas  poblados  y  los  cinco  municipios  menos poblados del país

# %%
asgard = asgard.sort_values(by='Población', ascending=False)

municipios_mas_poblados = asgard_sorted.head(5)

municipios_menos_poblados = asgard_sorted.tail(5)

print('Los 5 municipios más poblados:')
print(municipios_mas_poblados[['Municipio', 'Población']])

print('\nLos 5 municipios menos poblados:')
print(municipios_menos_poblados[['Municipio', 'Población']])
# Out:
# Los 5 municipios más poblados:
#         Municipio  Población
# 34       Madripur     998079
# 27    Villa Norte     997107
# 6        La Unión     986067
# 74  Gral Escobedo     974548
# 79    Yellow town     974324
#
# Los 5 municipios menos poblados:
#       Municipio  Población
# 85  Mar violeta      44585
# 26  Shelbyville      31535
# 39   Villa rosa      25538
# 14     Luz roja      14986
# 17  Ciudad Jedi      13666

# %% [markdown]
# ## f) El municipio más poblado de cada estado

# %%
municipio_mas_poblado_por_estado = asgard.sort_values('Población', ascending=False).groupby('Estado').first()
municipio_mas_poblado_por_estado
# Out:
#              País         Municipio  Población clasificacion
# Estado
# Alderaan   Asgard          Luz azul     914910  muy poblados
# Atlantis   Asgard      Mar amarillo     961061  muy poblados
# Endor      Asgard       Santa María     875371  muy poblados
# Genosha    Asgard   Villa Lannister     822654  muy poblados
# Gotham     Asgard       Playa Verde     918710  muy poblados
# Mandalore  Asgard         San Pedro     736716  muy poblados
# Mordor     Asgard          Madripur     998079  muy poblados
# Mustafar   Asgard       Villa Norte     997107  muy poblados
# Naboo      Asgard          Luz azul     602661  muy poblados
# Narnia     Asgard     Gral Escobedo     974548  muy poblados
# Pandora    Asgard  Villa Demogorgon     969140  muy poblados
# Sokovia    Asgard          La Unión     986067  muy poblados
# Tatooine   Asgard      Villa Marlon     925414  muy poblados
# Wakanda    Asgard          Redgreen     880858  muy poblados
# ...

# %% [markdown]
# ## 3.-Genera un grafico de barras de:
# a) Los 15 municipios más poblados de Asgard
#
# b) Cuantas peliculas hay de cada género

# %%
municipios_mas_poblados = asgard.sort_values(by='Población', ascending=False).head(15)
plt.bar(municipios_mas_poblados['Municipio'], municipios_mas_poblados['Población'])
plt.title('15 municipios más Poblados de Asgard')
plt.xlabel('Municipio')
plt.ylabel('Habitantes')
## Busqué ayuda adicional para quitar la notación cientifica en el eje y, ajustar el limite minimo y máximo y rotar las etiquetas del eje x para visualizar de mejor manera.
plt.ylim(min(municipios_mas_poblados['Población']) - 5000, max(municipios_mas_poblados['Población']) + 5000)
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
peliculas_por_genero = pelis['category'].value_counts()
plt.bar(peliculas_por_genero.index, peliculas_por_genero.values)
plt.xlabel('Género')
plt.ylabel('Número de Películas')
plt.title('Películas por Género')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
