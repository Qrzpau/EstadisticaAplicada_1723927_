# %% [markdown]
# ## Estadística Aplicada
#
# Sesión 6 - 21 agosto
#
# Paulina Quiroz Sánchez  1723927
#
# grupo 41

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nacimientos = pd.DataFrame({'municipio':['Mty', 'Apodaca', 'Escobedo', 'Santiago'], 'bb_nacidos' : [233, 569, 780, 123], 'moridos' : [123, 80, 23, 12]})

# %%
nacimientos = nacimientos.sort_values('bb_nacidos', ascending=False)
nacimientos
# Out:
#   municipio  bb_nacidos  moridos
# 2  Escobedo         780       23
# 1   Apodaca         569       80
# 0       Mty         233      123
# 3  Santiago         123       12

# %%
plt.bar(nacimientos['municipio'],nacimientos['bb_nacidos'])
plt.title('Nacimientos en N.L en 2020')
plt.xlabel('municipios')
plt.ylabel('Cantidad de bebes')
plt.show()

# %%
## Creamos una lista que se llamará edades

personas = ['Juan','Pedro','Ana','Ale']
edades = [23,18,20,31]

# %%
###
plt.scatter(personas,edades)
## quitar codigo de encima de forma correcta con .show
plt.show()

##Tambien se puede quitar con punto y coma
#plt.plot(personas,edades);

# graficas de barras
plt.bar(personas, edades);

# %%
## para personalizar el grafico
plt.bar(personas,edades, color=['blue', 'red', 'yellow','green'])
plt.xlabel('personas')
plt.ylabel('edad (años)')
plt.title('Edades de 4 desconocidos')
plt.show()

# %%
#fig es el nombre del lienzo
fig, (panel1, panel2) = plt.subplots(2,1)
fig.tight_layout()

##tight es para que se estiran similares

#gráfica1 nacimientos
x1 = nacimientos['municipio']
y1 = nacimientos['bb_nacidos']
panel1.bar(x1,y1)

#gráfica2 edades

x2 = personas
y2 = edades
panel2.bar(x2,y2)
plt.show()

# %% [markdown]
# # Ahora vamos a graficar con pandas
# dataframe['columna'].plot.tipo()

# %%
nacimientos.plot.bar()
# Out:
# <Axes: >

# %%
#cuando graficamos con pandas el eje x es el index, debemos hacer que los municipios sean el index para replicar grafica
nacimientos.plot.bar()
plt.title('')


#en pandas grafica todas las columnas, para mostrar solo una es necesario agregar
# nacimientos['moridos'].plot.bar()
#plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
#grafica de barras apiladas
nacimientos.plot.bar(stacked = True);

# %%
# grafico de areas
nacimientos.plot.area()
# Out:
# <Axes: >

# %%
#grafico de lineas
nacimientos.plot.line();

# %%
#histograma
nacimientos['bb_nacidos'].plot.hist();
